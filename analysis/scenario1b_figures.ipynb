# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
centr_acc_day1 = [98.72, 98.30, 98.26, 98.59, 98.67]
centr_tpr_day1 = [93.79, 97.24, 97.24, 97.24, 96.55]
centr_fpr_day1 = [1.18, 1.68, 1.72, 1.39, 1.29]

centr_acc_day1_mean = np.mean(centr_acc_day1)
centr_acc_day1_std = np.std(centr_acc_day1)
centr_tpr_day1_mean = np.mean(centr_tpr_day1)
centr_tpr_day1_std = np.std(centr_tpr_day1)
centr_fpr_day1_mean = np.mean(centr_fpr_day1)
centr_fpr_day1_std = np.std(centr_fpr_day1)

centr_acc_day2 = [98.82, 98.77, 98.74, 98.94, 99.10]
centr_tpr_day2 = [93.79, 93.10, 93.79, 93.79, 93.10]
centr_fpr_day2 = [1.07, 1.11, 1.16, 0.95, 0.77]

centr_acc_day2_mean = np.mean(centr_acc_day2)
centr_acc_day2_std = np.std(centr_acc_day2)
centr_tpr_day2_mean = np.mean(centr_tpr_day2)
centr_tpr_day2_std = np.std(centr_tpr_day2)
centr_fpr_day2_mean = np.mean(centr_fpr_day2)
centr_fpr_day2_std = np.std(centr_fpr_day2)

centr_acc_day3 = [99.06, 99.37, 99.23, 99.14, 99.14]
centr_tpr_day3 = [97.24, 95.17, 95.17, 97.24, 97.24]
centr_fpr_day3 = [0.91, 0.55, 0.69, 0.83, 0.83]

centr_acc_day3_mean = np.mean(centr_acc_day3)
centr_acc_day3_std = np.std(centr_acc_day3)
centr_tpr_day3_mean = np.mean(centr_tpr_day3)
centr_tpr_day3_std = np.std(centr_tpr_day3)
centr_fpr_day3_mean = np.mean(centr_fpr_day3)
centr_fpr_day3_std = np.std(centr_fpr_day3)

centr_acc_day4 = [98.79, 98.71, 98.45, 98.66, 98.79]
centr_tpr_day4 = [97.24, 97.24, 97.24, 97.24, 95.17]
centr_fpr_day4 = [1.18, 1.26, 1.23, 1.32, 1.14]

centr_acc_day4_mean = np.mean(centr_acc_day4)
centr_acc_day4_std = np.std(centr_acc_day4)
centr_tpr_day4_mean = np.mean(centr_tpr_day4)
centr_tpr_day4_std = np.std(centr_tpr_day4)
centr_fpr_day4_mean = np.mean(centr_fpr_day4)
centr_fpr_day4_std = np.std(centr_fpr_day4)


centr_acc_mean = np.array([centr_acc_day1_mean, centr_acc_day2_mean, centr_acc_day3_mean, centr_acc_day4_mean])
centr_acc_std = np.array([centr_acc_day1_std, centr_acc_day2_std, centr_acc_day3_std, centr_acc_day4_std])

centr_tpr_mean = np.array([centr_tpr_day1_mean, centr_tpr_day2_mean, centr_tpr_day3_mean, centr_tpr_day4_mean])
centr_tpr_std = np.array([centr_tpr_day1_std, centr_tpr_day2_std, centr_tpr_day3_std, centr_tpr_day4_std])

centr_fpr_mean = np.array([centr_fpr_day1_mean, centr_fpr_day2_mean, centr_fpr_day3_mean, centr_fpr_day4_mean])
centr_fpr_std = np.array([centr_fpr_day1_std, centr_fpr_day2_std, centr_fpr_day3_std, centr_fpr_day4_std])
days = ["Day 2", "Day 3", "Day 4", "Day 5"]

# %% [markdown]
# # FedAvg

# %%
acc_day1 = [97.30, 97.81, 97.28, 97.41, 96.39]
tpr_day1 = [93.10, 97.24, 93.79, 97.24, 97.24]
fpr_day1 = [1.83, 2.03, 2.04, 2.52, 3.79]

acc_day1_mean = np.mean(acc_day1)
acc_day1_std = np.std(acc_day1)
tpr_day1_mean = np.mean(tpr_day1)
tpr_day1_std = np.std(tpr_day1)
fpr_day1_mean = np.mean(fpr_day1)
fpr_day1_std = np.std(fpr_day1)

acc_day2 = [97.46, 97.28, 97.76, 97.66, 83.94]
tpr_day2 = [94.48, 94.48, 93.10, 93.10, 10.34]
fpr_day2 = [1.92, 2.12, 1.24, 1.36, 0.26]

acc_day2_mean = np.mean(acc_day2)
acc_day2_std = np.std(acc_day2)
tpr_day2_mean = np.mean(tpr_day2)
tpr_day2_std = np.std(tpr_day2)
fpr_day2_mean = np.mean(fpr_day2)
fpr_day2_std = np.std(fpr_day2)

acc_day3 = [98.24, 98.32, 90.54, 98.02, 97.92]
tpr_day3 = [97.24, 94.48, 43.45, 97.24, 97.24]
fpr_day3 = [1.59, 2.12, 0.33, 1.85, 1.98]

acc_day3_mean = np.mean(acc_day3)
acc_day3_std = np.std(acc_day3)
tpr_day3_mean = np.mean(tpr_day3)
tpr_day3_std = np.std(tpr_day3)
fpr_day3_mean = np.mean(fpr_day3)
fpr_day3_std = np.std(fpr_day3)

acc_day4 = [97.10, 98.15, 97.18, 97.92, 96.90]
tpr_day4 = [97.24, 97.24, 97.24, 97.24, 97.24]
fpr_day4 = [2.92, 1.66, 2.82, 1.93, 3.15]

acc_day4_mean = np.mean(acc_day4)
acc_day4_std = np.std(acc_day4)
tpr_day4_mean = np.mean(tpr_day4)
tpr_day4_std = np.std(tpr_day4)
fpr_day4_mean = np.mean(fpr_day4)
fpr_day4_std = np.std(fpr_day4)

fed_acc_mean = np.array([acc_day1_mean, acc_day2_mean, acc_day3_mean, acc_day4_mean])
fed_acc_std = np.array([acc_day1_std, acc_day2_std, acc_day3_std, acc_day4_std])

fed_tpr_mean = np.array([tpr_day1_mean, tpr_day2_mean, tpr_day3_mean, tpr_day4_mean])
fed_tpr_std = np.array([tpr_day1_std, tpr_day2_std, tpr_day3_std, tpr_day4_std])

fed_fpr_mean = np.array([fpr_day1_mean, fpr_day2_mean, fpr_day3_mean, fpr_day4_mean])
fed_fpr_std = np.array([fpr_day1_std, fpr_day2_std, fpr_day3_std, fpr_day4_std])

# %% [markdown]
# # FedAvgM(0.2)

# %%
acc_day1 = [98.43, 97.51, 97.85, 97.55, 96.55]
tpr_day1 = [93.10, 94.48, 93.10, 97.24, 97.24]
fpr_day1 = [0.48, 1.85, 1.2, 2.34, 3.55]

acc_day1_mean = np.mean(acc_day1)
acc_day1_std = np.std(acc_day1)
tpr_day1_mean = np.mean(tpr_day1)
tpr_day1_std = np.std(tpr_day1)
fpr_day1_mean = np.mean(fpr_day1)
fpr_day1_std = np.std(fpr_day1)

acc_day2 = [97.30, 98.01, 97.94, 97.52, 97.69]
tpr_day2 = [93.10, 97.24, 93.10, 93.10, 93.1]
fpr_day2 = [1.80, 1.84, 1.01, 1.54, 1.34]

acc_day2_mean = np.mean(acc_day2)
acc_day2_std = np.std(acc_day2)
tpr_day2_mean = np.mean(tpr_day2)
tpr_day2_std = np.std(tpr_day2)
fpr_day2_mean = np.mean(fpr_day2)
fpr_day2_std = np.std(fpr_day2)

acc_day3 = [98.05, 98.14, 98.24, 97.80, 98.36]
tpr_day3 = [96.55, 97.24, 97.24, 97.24, 97.24]
fpr_day3 = [1.85, 2.75, 1.58, 2.12, 1.43]

acc_day3_mean = np.mean(acc_day3)
acc_day3_std = np.std(acc_day3)
tpr_day3_mean = np.mean(tpr_day3)
tpr_day3_std = np.std(tpr_day3)
fpr_day3_mean = np.mean(fpr_day3)
fpr_day3_std = np.std(fpr_day3)

acc_day4 = [97.10, 97.79, 97.34, 97.74, 97.25]
tpr_day4 = [97.24, 93.79, 97.24, 97.24, 97.24]
fpr_day4 = [2.92, 2.36, 2.64, 2.15, 2.75]

acc_day4_mean = np.mean(acc_day4)
acc_day4_std = np.std(acc_day4)
tpr_day4_mean = np.mean(tpr_day4)
tpr_day4_std = np.std(tpr_day4)
fpr_day4_mean = np.mean(fpr_day4)
fpr_day4_std = np.std(fpr_day4)

fed_avg_acc_mean = np.array([acc_day1_mean, acc_day2_mean, acc_day3_mean, acc_day4_mean])
fed_avg_acc_std = np.array([acc_day1_std, acc_day2_std, acc_day3_std, acc_day4_std])

fed_avg_tpr_mean = np.array([tpr_day1_mean, tpr_day2_mean, tpr_day3_mean, tpr_day4_mean])
fed_avg_tpr_std = np.array([tpr_day1_std, tpr_day2_std, tpr_day3_std, tpr_day4_std])

fed_avg_fpr_mean = np.array([fpr_day1_mean, fpr_day2_mean, fpr_day3_mean, fpr_day4_mean])
fed_avg_fpr_std = np.array([fpr_day1_std, fpr_day2_std, fpr_day3_std, fpr_day4_std])

# %% [markdown]
# # Triplet loss

# %%
acc_day1 = [98.29, 98.14, 98.15, 97.87, 96.98]
tpr_day1 = [97.24, 97.24, 93.10, 97.24, 93.1]
fpr_day1 = [1.48, 1.66, 0.84, 1.99, 2.28]

acc_day1_mean = np.mean(acc_day1)
acc_day1_std = np.std(acc_day1)
tpr_day1_mean = np.mean(tpr_day1)
tpr_day1_std = np.std(tpr_day1)
fpr_day1_mean = np.mean(fpr_day1)
fpr_day1_std = np.std(fpr_day1)

acc_day2 = [98.55, 98.52, 98.16, 98.48, 98.09]
tpr_day2 = [93.10, 93.10, 93.10, 93.10, 90.34]
fpr_day2 = [0.3, 0.33, 0.79, 0.38, 0.26]

acc_day2_mean = np.mean(acc_day2)
acc_day2_std = np.std(acc_day2)
tpr_day2_mean = np.mean(tpr_day2)
tpr_day2_std = np.std(tpr_day2)
fpr_day2_mean = np.mean(fpr_day2)
fpr_day2_std = np.std(fpr_day2)

acc_day3 = [98.64, 98.64, 98.62, 98.73, 98.16]
tpr_day3 = [93.1, 93.1, 93.1, 93.79, 97.86]
fpr_day3 = [0.3, 0.3, 0.31, 0.33, 0.88]

acc_day3_mean = np.mean(acc_day3)
acc_day3_std = np.std(acc_day3)
tpr_day3_mean = np.mean(tpr_day3)
tpr_day3_std = np.std(tpr_day3)
fpr_day3_mean = np.mean(fpr_day3)
fpr_day3_std = np.std(fpr_day3)

acc_day4 = [98.64, 98.85, 98.33, 98.75, 97.73]
tpr_day4 = [97.24, 97.24, 95.17, 96.55, 97.24]
fpr_day4 = [1.09, 0.83, 1.06, 0.81, 2.18]

acc_day4_mean = np.mean(acc_day4)
acc_day4_std = np.std(acc_day4)
tpr_day4_mean = np.mean(tpr_day4)
tpr_day4_std = np.std(tpr_day4)
fpr_day4_mean = np.mean(fpr_day4)
fpr_day4_std = np.std(fpr_day4)

triplet_acc_mean = np.array([acc_day1_mean, acc_day2_mean, acc_day3_mean, acc_day4_mean])
triplet_acc_std = np.array([acc_day1_std, acc_day2_std, acc_day3_std, acc_day4_std])

triplet_tpr_mean = np.array([tpr_day1_mean, tpr_day2_mean, tpr_day3_mean, tpr_day4_mean])
triplet_tpr_std = np.array([tpr_day1_std, tpr_day2_std, tpr_day3_std, tpr_day4_std])

triplet_fpr_mean = np.array([fpr_day1_mean, fpr_day2_mean, fpr_day3_mean, fpr_day4_mean])
triplet_fpr_std = np.array([fpr_day1_std, fpr_day2_std, fpr_day3_std, fpr_day4_std])

# %%
plt.plot(range(4), centr_acc_mean, marker='^', label="Centralized")
plt.fill_between(range(4), centr_acc_mean+centr_acc_std, centr_acc_mean-centr_acc_std, alpha=0.2)

plt.plot(range(4), fed_acc_mean, marker='^', label="FedAvg")
plt.fill_between(range(4), fed_acc_mean+fed_acc_std, fed_acc_mean-fed_acc_std, alpha=0.2)

plt.plot(range(4), fed_avg_acc_mean, marker='^', label="FedAvgM(0.2)")
plt.fill_between(range(4), fed_avg_acc_mean+fed_avg_acc_std, fed_avg_acc_mean-fed_avg_acc_std, alpha=0.2)

plt.plot(range(4), triplet_acc_mean, marker='^', label="Triplet")
plt.fill_between(range(4), triplet_acc_mean+triplet_acc_std, triplet_acc_mean-triplet_acc_std, alpha=0.2)


plt.legend(loc=4)

plt.ylim(80, 100.0)
plt.ylabel("Accuracy (%)")
plt.xlabel("Testing day")
plt.xticks(range(4), days)
# plt.title("Accuracy (%) per day")
plt.grid(axis='y')

# %%
plt.plot(range(4), centr_tpr_mean, marker='^', label="Centralized")
plt.fill_between(range(4), centr_tpr_mean+centr_tpr_std, centr_tpr_mean-centr_tpr_std, alpha=0.2)

plt.plot(range(4), fed_tpr_mean, marker='^', label="FedAvg")
plt.fill_between(range(4), fed_tpr_mean+fed_tpr_std, fed_tpr_mean-fed_tpr_std, alpha=0.2)

plt.plot(range(4), fed_avg_tpr_mean, marker='^', label="FedAvgM(0.2)")
plt.fill_between(range(4), fed_avg_tpr_mean+fed_avg_tpr_std, fed_avg_tpr_mean-fed_avg_tpr_std, alpha=0.2)

plt.plot(range(4), triplet_tpr_mean, marker='^', label="Triplet")
plt.fill_between(range(4), triplet_tpr_mean+triplet_tpr_std, triplet_tpr_mean-triplet_tpr_std, alpha=0.2)

plt.legend(loc=4)

plt.ylim(50, 100.0)
plt.ylabel("TPR (%)")
plt.xlabel("Testing day")
plt.xticks(range(4), days)
# plt.title("TPR (%) per day")
plt.grid(axis='y')

# %%
triplet_fpr_mean
# Out:
# array([1.65 , 2.412, 0.424, 1.194])

# %%
plt.plot(range(4), centr_fpr_mean, marker='^', label="Centralized")
plt.fill_between(range(4), centr_fpr_mean+centr_fpr_std, centr_fpr_mean-centr_fpr_std, alpha=0.2)

plt.plot(range(4), fed_fpr_mean, marker='^', label="FedAvg")
plt.fill_between(range(4), fed_fpr_mean+fed_fpr_std, fed_fpr_mean-fed_fpr_std, alpha=0.2)

plt.plot(range(4), fed_avg_fpr_mean, marker='^', label="FedAvgM(0.2)")
plt.fill_between(range(4), fed_avg_fpr_mean+fed_avg_fpr_std, fed_avg_fpr_mean-fed_avg_fpr_std, alpha=0.2)

plt.plot(range(4), triplet_fpr_mean, marker='^', label="Triplet")
plt.fill_between(range(4), triplet_fpr_mean+triplet_fpr_std, triplet_fpr_mean-triplet_fpr_std, alpha=0.2)

plt.legend(loc=1)

plt.ylim(0, 10.0)
plt.ylabel("FPR (%)")
plt.xlabel("Testing day")

plt.xticks(range(4), days)
# plt.title("FPR (%) per day")
plt.grid(axis='y')

# %%
x = np.arange(len(days))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(8, 6))
# rects1 = ax.bar(x - width/2, dualFCNN_drop_means, width/4, yerr=dualFCNN_drop_std, capsize=5, label='dualFCNN (MC dropout)')
rects2 = ax.bar(x - width/4, centr_acc_mean, width/4, yerr=centr_acc_std, capsize=5, label='Centralized')
rects3 = ax.bar(x, fed_acc_mean, width/4, yerr=fed_acc_std, capsize=5, label='Federated')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)')
ax.set_xticks(x)
ax.set_xticklabels(days)
# ax.legend(loc=(1.04, 0.5))
ax.legend(loc=1)
ax.yaxis.grid(True, linestyle='-.')

# %%
x = np.arange(len(days))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(8, 6))
# rects1 = ax.bar(x - width/2, dualFCNN_drop_means, width/4, yerr=dualFCNN_drop_std, capsize=5, label='dualFCNN (MC dropout)')
rects2 = ax.bar(x - width/4, centr_tpr_mean, width/4, yerr=centr_tpr_std, capsize=5, label='Centralized')
rects3 = ax.bar(x, fed_tpr_mean, width/4, yerr=fed_tpr_std, capsize=5, label='Federated')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('TPR (%)')
ax.set_xticks(x)
ax.set_xticklabels(days)
# ax.legend(loc=(1.04, 0.5))
ax.legend()
ax.yaxis.grid(True, linestyle='-.')

# %%
x = np.arange(len(days))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(8, 6))
# rects1 = ax.bar(x - width/2, dualFCNN_drop_means, width/4, yerr=dualFCNN_drop_std, capsize=5, label='dualFCNN (MC dropout)')
rects2 = ax.bar(x - width/4, centr_fpr_mean, width/4, yerr=centr_fpr_std, capsize=5, label='Centralized')
rects3 = ax.bar(x, fed_fpr_mean, width/4, yerr=fed_fpr_std, capsize=5, label='Federated')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('FPR (%)')
ax.set_xticks(x)
ax.set_xticklabels(days)
# ax.legend(loc=(1.04, 0.5))
ax.legend()
ax.yaxis.grid(True, linestyle='-.')
